# %%
import requests

# %%
import requests
from bs4 import BeautifulSoup
import os
from urllib.parse import urljoin
import time

def download_audio_files(url):
    # Create a directory for downloads if it doesn't exist
    if not os.path.exists('downloaded_audio'):
        os.makedirs('downloaded_audio')
    
    # Get the webpage content
    try:
        response = requests.get(url)
        response.raise_for_status()
    except requests.RequestException as e:
        print(f"Error fetching the webpage: {e}")
        return
    
    # Parse the HTML
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all audio elements
    audio_elements = soup.find_all('audio')
    
    # Download each audio file
    for audio in audio_elements:
        source = audio.find('source')
        if source and source.get('src'):
            audio_url = urljoin(url, source['src'])
            filename = os.path.join('downloaded_audio', os.path.basename(audio_url))
            
            try:
                print(f"Downloading: {audio_url}")
                audio_response = requests.get(audio_url)
                audio_response.raise_for_status()
                
                with open(filename, 'wb') as f:
                    f.write(audio_response.content)
                print(f"Successfully downloaded: {filename}")
                
                # Add a small delay to be nice to the server
                time.sleep(1)
                
            except requests.RequestException as e:
                print(f"Error downloading {audio_url}: {e}")

if __name__ == "__main__":
    url = "https://www.orcasound.net/data/product/SRKW/call-catalog/2018-drafts/2018-12-07-spectrum_comparison.html"
    download_audio_files(url)
# Out:
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S01.mp3
# Successfully downloaded: downloaded_audio/FO-S01.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S02.mp3
# Successfully downloaded: downloaded_audio/FO-S02.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S03.mp3
# Successfully downloaded: downloaded_audio/FO-S03.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S04.mp3
# Successfully downloaded: downloaded_audio/FO-S04.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S05.mp3
# Successfully downloaded: downloaded_audio/FO-S05.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S06-L.mp3
# Successfully downloaded: downloaded_audio/FO-S06-L.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S06-a.mp3
# Successfully downloaded: downloaded_audio/FO-S06-a.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S06-b.mp3
# Successfully downloaded: downloaded_audio/FO-S06-b.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S06-c.mp3
# Successfully downloaded: downloaded_audio/FO-S06-c.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S07.mp3
# Successfully downloaded: downloaded_audio/FO-S07.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S09.mp3
# Successfully downloaded: downloaded_audio/FO-S09.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S10.mp3
# Successfully downloaded: downloaded_audio/FO-S10.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S13.mp3
# Successfully downloaded: downloaded_audio/FO-S13.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S14.mp3
# Successfully downloaded: downloaded_audio/FO-S14.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S16.mp3
# Successfully downloaded: downloaded_audio/FO-S16.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S17.mp3
# Successfully downloaded: downloaded_audio/FO-S17.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S18-R.mp3
# Successfully downloaded: downloaded_audio/FO-S18-R.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S19.mp3
# Successfully downloaded: downloaded_audio/FO-S19.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S22-a.mp3
# Successfully downloaded: downloaded_audio/FO-S22-a.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S22-b.mp3
# Successfully downloaded: downloaded_audio/FO-S22-b.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S30.mp3
# Successfully downloaded: downloaded_audio/FO-S30.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S31-a.mp3
# Successfully downloaded: downloaded_audio/FO-S31-a.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S31-b.mp3
# Successfully downloaded: downloaded_audio/FO-S31-b.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S31-c.mp3
# Successfully downloaded: downloaded_audio/FO-S31-c.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S33-R.mp3
# Successfully downloaded: downloaded_audio/FO-S33-R.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S33-RJ-a.mp3
# Successfully downloaded: downloaded_audio/FO-S33-RJ-a.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S33-RJ-b.mp3
# Successfully downloaded: downloaded_audio/FO-S33-RJ-b.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S33-RJ-c.mp3
# Successfully downloaded: downloaded_audio/FO-S33-RJ-c.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S33-RJ-d.mp3
# Successfully downloaded: downloaded_audio/FO-S33-RJ-d.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S34-R.mp3
# Successfully downloaded: downloaded_audio/FO-S34-R.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S35-R-a.mp3
# Successfully downloaded: downloaded_audio/FO-S35-R-a.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S35-R-b.mp3
# Successfully downloaded: downloaded_audio/FO-S35-R-b.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S36.mp3
# Successfully downloaded: downloaded_audio/FO-S36.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S37.mp3
# Successfully downloaded: downloaded_audio/FO-S37.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S38-a.mp3
# Successfully downloaded: downloaded_audio/FO-S38-a.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S38-b.mp3
# Successfully downloaded: downloaded_audio/FO-S38-b.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S39.mp3
# Successfully downloaded: downloaded_audio/FO-S39.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S40-R-a.mp3
# Successfully downloaded: downloaded_audio/FO-S40-R-a.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S40-R-b.mp3
# Successfully downloaded: downloaded_audio/FO-S40-R-b.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S42.mp3
# Successfully downloaded: downloaded_audio/FO-S42.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S44-a.mp3
# Successfully downloaded: downloaded_audio/FO-S44-a.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S44-b.mp3
# Successfully downloaded: downloaded_audio/FO-S44-b.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S45.mp3
# Successfully downloaded: downloaded_audio/FO-S45.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S46-b.mp3
# Successfully downloaded: downloaded_audio/FO-S46-b.mp3
# Downloading: http://www.orcasound.net/data/product/SRKW/call-catalog/no-narration_flac+mp3+ogg+spectrograms/mp3/FO-S46.mp3
# Successfully downloaded: downloaded_audio/FO-S46.mp3
